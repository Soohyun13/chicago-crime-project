# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
chicago = pd.read_csv('/content/drive/MyDrive/final_csv/chicago_final.csv')

# %%
chicago.head()
# Out:
#         ID Case Number                 Date                    Block  IUCR  \
# 0  4676906    HM278933  2003-03-01 00:00:00          004XX W 42ND PL  2825
# 1  4677901    HM275615  2003-05-01 01:00:00       111XX S NORMAL AVE  0841
# 2  4791194    HM403711  2001-01-01 11:00:00  114XX S ST LAWRENCE AVE  0266
# 3  4679521    HM216293  2003-03-15 00:00:00       090XX S RACINE AVE  5007
# 4  4680124    HM282389  2003-01-01 00:00:00    009XX S SPAULDING AVE  0840
#
#           Primary Type                     Description  \
# 0        OTHER OFFENSE         HARASSMENT BY TELEPHONE
# 1                THEFT  FINANCIAL ID THEFT:$300 &UNDER
# 2  CRIM SEXUAL ASSAULT                       PREDATORY
# 3        OTHER OFFENSE         OTHER WEAPONS VIOLATION
# 4                THEFT   FINANCIAL ID THEFT: OVER $300
#
#       Location Description  Arrest  Domestic  ...  FBI Code  X Coordinate  \
# 0                RESIDENCE   False      True  ...        26     1173974.0
# 1                RESIDENCE   False     False  ...        06     1174948.0
# 2                RESIDENCE    True      True  ...        02     1182247.0
# 3  RESIDENCE PORCH/HALLWAY   False     False  ...        26     1169911.0
# 4                RESIDENCE   False     False  ...        06     1154521.0
#
#    Y Coordinate    Year              Updated On   Latitude  Longitude  \
# 0     1876757.0  2003.0  04/15/2016 08:55:02 AM  41.817229 -87.637328
# 1     1831051.0  2003.0  04/15/2016 08:55:02 AM  41.691785 -87.635116
# 2     1829375.0  2001.0  08/29/2006 03:46:28 AM  41.687020 -87.608445
# 3     1844832.0  2003.0  04/15/2016 08:55:02 AM  41.729712 -87.653159
# 4     1895755.0  2003.0  04/15/2016 08:55:02 AM  41.869772 -87.708180
#
#                         Location      F_Date      Time
# 0  (41.817229156, -87.637328162)  2003-03-01  00:00:00
# 1  (41.691784636, -87.635115968)  2003-05-01  01:00:00
# 2   (41.687020002, -87.60844523)  2001-01-01  11:00:00
# 3  (41.729712374, -87.653158513)  2003-03-15  00:00:00
# 4  (41.869772159, -87.708180162)  2003-01-01  00:00:00
#
# [5 rows x 24 columns]

# %%
chicago.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location', 'F_Date', 'Time'],
#       dtype='object')

# %%
# 숫자형 변수 통계량
chicago.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  7.836600e+06  7.836600e+06  7.836600e+06  7.836600e+06    7.836600e+06
# mean   5.910676e+06  1.197667e+03  1.131164e+01  2.260282e+01    3.766632e+01
# std    2.553965e+06  7.041774e+02  6.943899e+00  1.382085e+01    2.155284e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    3.852383e+06  6.230000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    6.148468e+06  1.111000e+03  1.000000e+01  2.200000e+01    3.200000e+01
# 75%    7.700037e+06  1.732000e+03  1.700000e+01  3.400000e+01    5.800000e+01
# max    1.082334e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  7.836600e+06  7.836600e+06  7.836600e+06  7.836600e+06  7.836600e+06
# mean   1.164466e+06  1.885550e+06  2.007655e+03  4.184155e+01 -8.767199e+01
# std    1.743290e+04  3.307896e+04  4.037070e+00  9.103737e-02  6.300459e-02
# min    0.000000e+00  0.000000e+00  2.001000e+03  3.661945e+01 -9.168657e+01
# 25%    1.152890e+06  1.858987e+06  2.005000e+03  4.176850e+01 -8.771401e+01
# 50%    1.165915e+06  1.890066e+06  2.008000e+03  4.185389e+01 -8.766642e+01
# 75%    1.176338e+06  1.909359e+06  2.010000e+03  4.190698e+01 -8.762854e+01
# max    1.205119e+06  1.951573e+06  2.017000e+03  4.202271e+01 -8.752453e+01

# %%
# 범주형 변수의 빈도수
chicago['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1614757
# BATTERY                              1430668
# CRIMINAL DAMAGE                       915460
# NARCOTICS                             871594
# OTHER OFFENSE                         485914
# ASSAULT                               477364
# BURGLARY                              467232
# MOTOR VEHICLE THEFT                   365708
# ROBBERY                               297397
# DECEPTIVE PRACTICE                    268522
# CRIMINAL TRESPASS                     227640
# PROSTITUTION                           85537
# WEAPONS VIOLATION                      76629
# PUBLIC PEACE VIOLATION                 58169
# OFFENSE INVOLVING CHILDREN             48434
# CRIM SEXUAL ASSAULT                    28033
# SEX OFFENSE                            27139
# GAMBLING                               18655
# LIQUOR LAW VIOLATION                   17317
# INTERFERENCE WITH PUBLIC OFFICER       15568
# ARSON                                  12955
# HOMICIDE                                8988
# KIDNAPPING                              7671
# INTIMIDATION                            4581
# STALKING                                3635
# OBSCENITY                                471
# PUBLIC INDECENCY                         162
# OTHER NARCOTIC VIOLATION                 143
# CONCEALED CARRY LICENSE VIOLATION         84
# NON-CRIMINAL                              80
# NON - CRIMINAL                            38
# RITUALISM                                 29
# HUMAN TRAFFICKING                         20
# NON-CRIMINAL (SUBJECT SPECIFIED)           4
# DOMESTIC VIOLENCE                          2
# Name: count, dtype: int64

# %%
# 'Date' 컬럼에서 요일, 월, 시간 추출
chicago['Date'] = pd.to_datetime(chicago['Date'])
chicago['Hour'] = chicago['Date'].dt.hour
chicago['Weekday'] = chicago['Date'].dt.weekday
chicago['Month'] = chicago['Date'].dt.month

# 시간대별 범죄 발생 건수
sns.countplot(x='Hour', data=chicago)
plt.title('Crime by Hour')
plt.show()

# 월별 범죄 발생 건수
sns.countplot(x='Month', data=chicago)
plt.title('Crime by Month')
plt.show()

# %% [markdown]
# - 5-8월 여름에 더 범죄가 늘어나는 추이를 보임
# - 더위로 인한 스트레스가 공격성과 폭력성을 높일 수 있음
# - 더운 날씨로 인해 사람들이 더 많이 외출하고 활동하므로 범죄 기회가 증가
# - 창문을 열어두거나 야외 활동이 늘어나면서 주거침입이나 절도의 기회가 증가
# - 시카고의 5-8월 날씨
#     - 6-8월: 평균 기온 22-29°C이며 습도가 높고 매우 덥습니다.
#     - 특히 7월이 가장 더운 달이며 때로는 35°C 이상 올라가기도 합니다.

# 7836393      1
# 7836436      1
# 7836443      1
# 7836444      1
# 7836446      1
# 7836457      1
# 7836458      1
# 7836459      1
# 7836466      1
# 7836467      1
# 7836508      1
# 7836509      1
# 7836510      1
# 7836528      1
# 7836539      1
# 7836540      1
# 7836541      1
#
# [30 rows x 27 columns]

# %%
# 히스토그램
plt.hist(chicago['Year'], bins=range(2001, 2018), edgecolor='black')
plt.title('Year Distribution')
plt.show()

# %%
# 숫자형 컬럼만 선택
numeric_columns = chicago.select_dtypes(include=['number']).columns

# 숫자형 컬럼으로 상관 행렬 계산
corr_matrix = chicago[numeric_columns].corr()

# 상관 행렬 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### 범죄유형에 따른 체포비율

# %%
import numpy as np

# Primary Type의 고유 값 리스트
primary_types = chicago['Primary Type'].value_counts().index

# 5개씩 나누기
chunks = [primary_types[i:i+5] for i in range(0, len(primary_types), 5)]

# 각 그룹에 대해 개별적으로 그래프 그리기
for chunk in chunks:
    plt.figure(figsize=(12, 6))
    sns.countplot(x='Primary Type', hue='Arrest', data=chicago[chicago['Primary Type'].isin(chunk)])
    plt.title(f'Crime Type vs Arrest (Types: {", ".join(chunk)})')
    plt.show()

# %% [markdown]
# 체포건이 더 많은 범죄: NARCOTICS (마약), CRIMINAL TRESPASS (불법 침입), WEAPONS VIOLATION (무기 위반), PUBLIC PEACE VIOLATION (공공 질서 위반), PROSTITUTION (매춘), INTERFERENCE WITH PUBLIC OFFICER (공무 방해), GAMBLING (도박), LIQUOR LAW VIOLATION (주류법 위반), OBSCENITY (음란물), OTHER NARCOTIC VIOLATION (기타 마약 위반), PUBLIC INDECENCY (공공장소에서의 추잡한 행위), CARRY LICENSE VIOLATION (허가 없이 무기 소지)

# %% [markdown]
# #### 체포율이 높을 수록 범죄가 감소하는지 확인

# %% [markdown]
# - 전체 기간 범죄 유형별 체포율

# %%
# 체포율이 높을 수록 점점 해당 범죄가 감소하는지
# True(체포됨) → 1, False(체포 안됨) → 0 이므로, mean()을 취하면 체포율
arrest_rate = chicago.groupby('Primary Type')['Arrest'].mean().reset_index()
arrest_rate.rename(columns={'Arrest': 'Arrest Rate'}, inplace=True)

# %%
arrest_rate.head()
# Out:
#                         Primary Type  Arrest Rate
# 0                              ARSON     0.132381
# 1                            ASSAULT     0.237117
# 2                            BATTERY     0.229284
# 3                           BURGLARY     0.057597
# 4  CONCEALED CARRY LICENSE VIOLATION     0.857143

# %%
# 연도별 발생 건수
crime_trend = chicago.groupby(['Year', 'Primary Type']).size().reset_index(name='Crime Count')

# %%
crime_trend.head()
# Out:
#    Year         Primary Type  Crime Count
# 0  2001                ARSON         1168
# 1  2001              ASSAULT        36298
# 2  2001              BATTERY       108144
# 3  2001             BURGLARY        30139
# 4  2001  CRIM SEXUAL ASSAULT         2087

# %%
# 체포율이 높은 상위 5개 범죄 유형
top_arrest_types = arrest_rate.sort_values(by='Arrest Rate', ascending=False).head(5)['Primary Type']

# 체포율이 높은 범죄의 연도별 발생 추이
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Crime Count', hue='Primary Type',
             data=crime_trend[crime_trend['Primary Type'].isin(top_arrest_types)])
plt.title('Crime Trend for High Arrest Rate Crimes')
plt.legend(title="Primary Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# 체포율이 낮은 하위 5개 범죄 유형
low_arrest_types = arrest_rate.sort_values(by='Arrest Rate', ascending=True).head(5)['Primary Type']

# 체포율이 낮은 범죄의 연도별 발생 추이
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Crime Count', hue='Primary Type',
             data=crime_trend[crime_trend['Primary Type'].isin(low_arrest_types)])
plt.title('Crime Trend for Low Arrest Rate Crimes')
plt.legend(title="Primary Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# -> 유의미하진 않음 전체적으로 감소추세

# %% [markdown]
# - 연도별 범죄 유형별 체포율

# %%
# 연도별 + 범죄 유형별 체포율 계산
yearly_arrest_rate = chicago.groupby(['Year', 'Primary Type'])['Arrest'].mean().reset_index()
yearly_arrest_rate.rename(columns={'Arrest': 'Arrest Rate'}, inplace=True)

# 연도별 범죄 발생 건수 계산
crime_trend = chicago.groupby(['Year', 'Primary Type']).size().reset_index(name='Crime Count')

# 체포율과 결합 (연도별로 체포율 다르게 계산)
crime_trend = crime_trend.merge(yearly_arrest_rate, on=['Year', 'Primary Type'], how='left')

# 데이터 확인
crime_trend.head()
# Out:
#    Year         Primary Type  Crime Count  Arrest Rate
# 0  2001                ARSON         1168     0.180651
# 1  2001              ASSAULT        36298     0.230233
# 2  2001              BATTERY       108144     0.220872
# 3  2001             BURGLARY        30139     0.064534
# 4  2001  CRIM SEXUAL ASSAULT         2087     0.234787

# %%
# 체포율이 높은 상위 5개 범죄 유형 선택
top5_arrest_types = crime_trend.groupby('Primary Type')['Arrest Rate'].mean().nlargest(5).index

plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Arrest Rate', hue='Primary Type',
             data=crime_trend[crime_trend['Primary Type'].isin(top5_arrest_types)])
plt.title('Yearly Arrest Rate (Top 5 High Arrest Crimes)')
plt.xlabel('Year')
plt.ylabel('Arrest Rate')
plt.legend(title='Primary Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# 체포율이 높은 상위 5개 범죄 유형의 발생건수 추이
top5_arrest_types = crime_trend.groupby('Primary Type')['Arrest Rate'].mean().nlargest(5).index

plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Crime Count', hue='Primary Type',
             data=crime_trend[crime_trend['Primary Type'].isin(top5_arrest_types)])
plt.title('Yearly Crime Count (Top 5 High Arrest Crimes)')
plt.xlabel('Year')
plt.ylabel('Crime Count')
plt.legend(title='Primary Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# - 각 연도별로 체포율 상위 5개 범죄 찾기

# %%
# 연도 리스트 가져오기
years = crime_trend['Year'].unique()
# 결과를 저장할 빈 리스트 생성
top5_arrest_by_year_list = []

# 연도별로 반복
for year in years:
    # 해당 연도의 데이터 필터링
    yearly_data = crime_trend[crime_trend['Year'] == year]

    # 체포율(Arrest Rate)이 높은 상위 5개 범죄 유형 선택
    top5_crimes = yearly_data.nlargest(5, 'Arrest Rate')

    # 리스트에 추가
    top5_arrest_by_year_list.append(top5_crimes)

# 리스트를 하나의 데이터프레임으로 변환
top5_arrest_by_year = pd.concat(top5_arrest_by_year_list).reset_index(drop=True)

# 데이터 확인
top5_arrest_by_year
# Out:
#     Year              Primary Type  Crime Count  Arrest Rate
# 0   2001         DOMESTIC VIOLENCE            2     1.000000
# 1   2001                 OBSCENITY           22     1.000000
# 2   2001  OTHER NARCOTIC VIOLATION            7     1.000000
# 3   2001          PUBLIC INDECENCY           10     1.000000
# 4   2001                 NARCOTICS        59608     0.999849
# ..   ...                       ...          ...          ...
# 76  2016              PROSTITUTION          780     1.000000
# 77  2016          PUBLIC INDECENCY           10     1.000000
# 78  2016                 NARCOTICS        10671     0.999438
# 79  2016      LIQUOR LAW VIOLATION          210     0.995238
# 80  2017                  HOMICIDE           30     0.000000
#
# [81 rows x 4 columns]

# %%
top5_arrest_by_year[top5_arrest_by_year['Year'] == 2017]
# Out:
#     Year Primary Type  Crime Count  Arrest Rate
# 80  2017     HOMICIDE           30          0.0

# %%
# 연도 목록 가져오기
years = sorted(top5_arrest_by_year['Year'].unique())

# 서브플롯 설정 (한 줄에 3개씩)
num_years = len(years)
cols = 3  # 한 줄에 3개씩 그래프 배치
rows = (num_years // cols) + (num_years % cols > 0)  # 필요한 행 개수 계산

fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 5))  # 전체 그래프 크기 조절
axes = axes.flatten()  # 다차원 배열을 1차원으로 변환

# 연도별로 그래프 생성
for i, year in enumerate(years):
    ax = axes[i]  # 해당 연도에 대한 서브플롯 선택
    yearly_data = top5_arrest_by_year[top5_arrest_by_year['Year'] == year]

    # 막대 그래프 그리기
    sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')

    ax.set_title(f'Top 5 Arrest Rate Crimes in {year}')
    ax.set_xlabel('Crime Count')
    ax.set_ylabel('Primary Type')

# 빈 서브플롯 숨기기
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')
# <ipython-input-46-a3adf292b9e0>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=yearly_data, x='Crime Count', y='Primary Type', ax=ax, palette='viridis')

# %% [markdown]
# -> 전반적으로 마약(NARCOTICS)의 체포율이 높지만 감소하고 있다고는 볼 수 없음. 체포율이 미치는 영향이 크다고 보기 어려움

# %% [markdown]
# ### 전체 범죄 발생비율 확인

# %%
# 범죄 유형별 발생 건수 비율 계산
crime_ratio = chicago['Primary Type'].value_counts(normalize=True) * 100
print(crime_ratio)
# Out:
# Primary Type
# THEFT                                20.605326
# BATTERY                              18.256234
# CRIMINAL DAMAGE                      11.681852
# NARCOTICS                            11.122094
# OTHER OFFENSE                         6.200572
# ASSAULT                               6.091468
# BURGLARY                              5.962177
# MOTOR VEHICLE THEFT                   4.666667
# ROBBERY                               3.794975
# DECEPTIVE PRACTICE                    3.426511
# CRIMINAL TRESPASS                     2.904831
# PROSTITUTION                          1.091507
# WEAPONS VIOLATION                     0.977835
# PUBLIC PEACE VIOLATION                0.742273
# OFFENSE INVOLVING CHILDREN            0.618049
# CRIM SEXUAL ASSAULT                   0.357719
# SEX OFFENSE                           0.346311
# GAMBLING                              0.238050
# LIQUOR LAW VIOLATION                  0.220976
# INTERFERENCE WITH PUBLIC OFFICER      0.198658
# ARSON                                 0.165314
# HOMICIDE                              0.114693
# KIDNAPPING                            0.097887
# INTIMIDATION                          0.058456
# STALKING                              0.046385
# OBSCENITY                             0.006010
# PUBLIC INDECENCY                      0.002067
# OTHER NARCOTIC VIOLATION              0.001825
# CONCEALED CARRY LICENSE VIOLATION     0.001072
# NON-CRIMINAL                          0.001021
# NON - CRIMINAL                        0.000485
# RITUALISM                             0.000370
# HUMAN TRAFFICKING                     0.000255
# NON-CRIMINAL (SUBJECT SPECIFIED)      0.000051
# DOMESTIC VIOLENCE                     0.000026
# Name: proportion, dtype: float64

# %%
# 0.9% 이하의 범죄를 "ETC"
threshold = 0.9  # 1% 이하를 묶을 기준
crime_ratio_etc = crime_ratio[crime_ratio > threshold]
crime_ratio_etc['ETC'] = crime_ratio[crime_ratio <= threshold].sum()

# 파이 차트 그리기
plt.figure(figsize=(12, 8))
plt.pie(crime_ratio_etc, labels=crime_ratio_etc.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Crime Types Proportion in Chicago (with ETC)')
plt.axis('equal')  # 원형 유지
plt.show()

# %% [markdown]
# - 범죄 발생률이 제일 높은 THEFT의 년도별 추이와 체포율

# %%
# THEFT 범죄 데이터 필터링
theft_data = chicago[chicago['Primary Type'] == 'THEFT']

# 1. THEFT 범죄의 년도별 발생 건수 추이
theft_yearly_count = theft_data.groupby('Year').size().reset_index(name='Crime Count')

# 2. THEFT 범죄의 년도별 체포율 (Arrest Rate)
theft_yearly_arrest_rate = theft_data.groupby('Year')['Arrest'].mean().reset_index()
theft_yearly_arrest_rate.rename(columns={'Arrest': 'Arrest Rate'}, inplace=True)

# 그래프 그리기
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# 1. THEFT 범죄의 년도별 발생 건수 추이
sns.lineplot(x='Year', y='Crime Count', data=theft_yearly_count, ax=ax1, marker='o', color='blue')
ax1.set_title('THEFT Crime Count by Year')
ax1.set_xlabel('Year')
ax1.set_ylabel('Crime Count')

# 2. THEFT 범죄의 년도별 체포율
sns.lineplot(x='Year', y='Arrest Rate', data=theft_yearly_arrest_rate, ax=ax2, marker='o', color='red')
ax2.set_title('THEFT Arrest Rate by Year')
ax2.set_xlabel('Year')
ax2.set_ylabel('Arrest Rate')

plt.tight_layout()  # 레이아웃 자동 조정
plt.show()

# %%
# THEFT 범죄 데이터 필터링
theft_data = chicago[chicago['Primary Type'] == 'THEFT']

# 1. THEFT 범죄의 년도별 발생 건수 추이
theft_yearly_count = theft_data.groupby('Year').size().reset_index(name='Crime Count')

# 2. THEFT 범죄의 년도별 체포율 (Arrest Rate)
theft_yearly_arrest_rate = theft_data.groupby('Year')['Arrest'].mean().reset_index()
theft_yearly_arrest_rate.rename(columns={'Arrest': 'Arrest Rate'}, inplace=True)

# 그래프 그리기 (두 축을 사용하여 겹쳐서 시각화)
fig, ax1 = plt.subplots(figsize=(14, 6))

# 1. THEFT 범죄의 년도별 발생 건수 추이
sns.lineplot(x='Year', y='Crime Count', data=theft_yearly_count, ax=ax1, marker='o', color='blue')
ax1.set_title('THEFT Crime Count and Arrest Rate by Year')
ax1.set_xlabel('Year')
ax1.set_ylabel('Crime Count', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# 2. THEFT 범죄의 년도별 체포율
ax2 = ax1.twinx()  # 두 번째 y축 생성
sns.lineplot(x='Year', y='Arrest Rate', data=theft_yearly_arrest_rate, ax=ax2, marker='o', color='red')
ax2.set_ylabel('Arrest Rate', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.tight_layout()  # 레이아웃 조정
plt.show()

# %% [markdown]
# 체포율이 전반적으로 하락세를 보이고 있고 절도건수또한 2005-2011년을 제외하고 하락 추세이다.
#
# 2005년 이후로 체포율이 하락하면서 절도가 증가했지만, 2010년에 체포율이 최하위기록을 보여주고 있는 반면 절도 범죄는 감소하는 추세를 보여주었다.

# %% [markdown]
# - 주거지역 별 범죄 발생률(Location Description)

# %%
location_crime_count = chicago['Location Description'].value_counts() # 170개의 지역

# %%
location_crime_top5 = location_crime_count.sort_values(ascending=False).head(5)

# %%
df_2001 = chicago[chicago['Year'] == 2001]
df_2001.shape
# Out:
# (565115, 27)

# %%
# 1. 상위 5개 주거지역만 추출
top_5_locations = location_crime_top5.index

# 2. 주거지역별 범죄 발생 건수와 범죄 유형 집계
location_crime_detail = chicago.groupby(['Location Description', 'Primary Type']).size().reset_index(name='Crime Count')

# 3. 상위 5 주거지역에 대해서만 필터링
top_5_location_crime = location_crime_detail[location_crime_detail['Location Description'].isin(top_5_locations)]

# 4. 주거지역별로 범죄 발생 건수를 내림차순 정렬하고 Rank 부여
top_5_location_crime['Rank'] = top_5_location_crime.groupby('Location Description')['Crime Count'].rank(method='first', ascending=False)

# 5. Rank가 1~3인 경우만 필터링 (상위 3개 범죄)
top_3_crimes_by_location = top_5_location_crime[top_5_location_crime['Rank'] <= 3]

# 6. 시각화 (주거 지역별로 subplot을 나눠서 상위 3개 범죄 유형을 표시)
num_locations = len(top_5_locations)
fig, axes = plt.subplots(num_locations, 1, figsize=(15, 5 * num_locations))

# 각 주거지역에 대해 subplot을 생성
for i, location in enumerate(top_5_locations):
    ax = axes[i] if num_locations > 1 else axes  # 여러 개의 subplot일 경우 인덱스로 접근
    data = top_3_crimes_by_location[top_3_crimes_by_location['Location Description'] == location]

    sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')
    ax.set_title(f'Top 3 Crimes at {location}')
    ax.set_xlabel('Crime Count')
    ax.set_ylabel('Crime Type')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-71-f12acb98b9bb>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_5_location_crime['Rank'] = top_5_location_crime.groupby('Location Description')['Crime Count'].rank(method='first', ascending=False)
# <ipython-input-71-f12acb98b9bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')
# <ipython-input-71-f12acb98b9bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')
# <ipython-input-71-f12acb98b9bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')
# <ipython-input-71-f12acb98b9bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')
# <ipython-input-71-f12acb98b9bb>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crime Count', y='Primary Type', data=data, ax=ax, palette='viridis')

# %%
# 6. 주거지역별로 상위 3개 범죄를 하나의 표로 만들기
top_3_crimes_pivot = top_3_crimes_by_location.pivot_table(index='Location Description',
                                                         columns='Rank',
                                                         values='Primary Type',
                                                         aggfunc='first')

# 7. 결과 출력
top_3_crimes_pivot.columns = [f'Crime {i}' for i in range(1, 4)]  # 열 이름을 Crime 1, Crime 2, Crime 3으로 변경
top_3_crimes_pivot = top_3_crimes_pivot.reset_index()  # Index를 초기화하여 보기 좋게 정리

# 출력
print(top_3_crimes_pivot)
# Out:
#   Location Description    Crime 1          Crime 2          Crime 3
# 0            APARTMENT    BATTERY         BURGLARY  CRIMINAL DAMAGE
# 1                OTHER      THEFT  CRIMINAL DAMAGE          BATTERY
# 2            RESIDENCE    BATTERY    OTHER OFFENSE  CRIMINAL DAMAGE
# 3             SIDEWALK  NARCOTICS          BATTERY          ROBBERY
# 4               STREET      THEFT  CRIMINAL DAMAGE        NARCOTICS

# %% [markdown]
# ### 체포율

# %%
# 전체 범죄에서 체포가 발생한 건수
total_crimes = chicago.shape[0]

# 체포가 발생한 범죄의 건수
arrested_crimes = chicago[chicago['Arrest'] == True].shape[0]

# 체포 비율 계산
arrest_rate = arrested_crimes / total_crimes * 100

# 결과 출력
print(f"전체 범죄 중 {arrest_rate:.2f}%가 체포로 이어졌습니다.")
# Out:
# 전체 범죄 중 28.40%가 체포로 이어졌습니다.

# %%
# 범죄 유형별 체포율 계산
crime_arrest_rate = chicago.groupby('Primary Type')['Arrest'].mean().reset_index()

# 체포율이 낮은 범죄 유형 Top 5
low_arrest_rate = crime_arrest_rate.sort_values(by='Arrest', ascending=True).head(5)

# 체포율이 높은 범죄 유형 Top 5
high_arrest_rate = crime_arrest_rate.sort_values(by='Arrest', ascending=False).head(5)

# 결과 출력
print("체포율이 낮은 범죄 유형 Top 5:")
print(low_arrest_rate)

print("\n체포율이 높은 범죄 유형 Top 5:")
print(high_arrest_rate)
# Out:
# 체포율이 낮은 범죄 유형 Top 5:
#            Primary Type    Arrest
# 3              BURGLARY  0.057597
# 6       CRIMINAL DAMAGE  0.070985
# 20         NON-CRIMINAL  0.087500
# 17  MOTOR VEHICLE THEFT  0.089798
# 30              ROBBERY  0.099332
#
# 체포율이 높은 범죄 유형 Top 5:
#             Primary Type    Arrest
# 9      DOMESTIC VIOLENCE  1.000000
# 26          PROSTITUTION  0.995043
# 18             NARCOTICS  0.992725
# 10              GAMBLING  0.991745
# 16  LIQUOR LAW VIOLATION  0.990068

# %%
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# 2001년 데이터 필터링
chicago_2001 = chicago[chicago['Year'] == 2001]
chicago_2001.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location', 'F_Date', 'Time', 'Hour', 'Weekday', 'Month'],
#       dtype='object')

# %% [markdown]
# - **결론**
#     - 범죄 해결률이 낮음 - 전체 범죄 중 28.40%만이 체포로 이어짐⁠⁠
#     - 범죄 유형별 체포율 차이가 큼:
#
#         마약, 불법 침입, 무기 위반, 매춘 등 단속 중심 범죄는 체포율이 높음⁠⁠
#
#     - 절도 범죄(가장 빈번한 범죄) 특징
#
#         체포율이 전반적으로 하락 추세 2005-2011년 사이 범죄 건수가 증가했으나, 이후 감소세로 전환
#
#     - 주거지역별 주요 범죄 패턴:
#
#         아파트: 구타, 주거침입, 기물파손이 가장 빈번
#
#         거리: 절도, 기물파손, 마약 순으로 발생
#
#         보도: 마약, 구타, 강도가 주요 범죄
